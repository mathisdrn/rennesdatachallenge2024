# %% [markdown]
# ## Rennes Data Challenge 2023
#
# Mathis Derenne - Arshia xx - Odilon xx
#
# ---

# %% [markdown]
# ## Python Environment Setup

# %%
import platform, os, sys

print(f"Platform : {platform.system()}")
print(f"Arch : {platform.machine()}")
print(f"Current virtual environment : {os.environ.get('VIRTUAL_ENV')}")

print("Shell virtual environment :")
# !python -c "import sys; print(sys.prefix)"
# Out:
# Platform : Darwin
# Arch : arm64
# Current virtual environment : None
# Shell virtual environment :
# /Users/mathisderenne/anaconda3

# %% [markdown]
# ### Install TA-Lib dependencies

# %%
if platform.system() == "Darwin":
    # if apple silicon
    if platform.machine() == "arm64":
        # !arch -arm64 brew install ta-lib
    else:
        # !brew install ta-lib
    
    # !export TA_INCLUDE_PATH="$(brew --prefix ta-lib)/include"
    # !export TA_LIBRARY_PATH="$(brew --prefix ta-lib)/lib"

else:
    print("Please refer to instructions at : https://pypi.org/project/TA-Lib/")
# Out:
# ==> Downloading https://formulae.brew.sh/api/formula.jws.json
# ######################################################################### 100.0%
# ==> Downloading https://formulae.brew.sh/api/cask.jws.json
# ######################################################################### 100.0%
# Warning: ta-lib 0.4.0 is already installed and up-to-date.
# To reinstall 0.4.0, run:
#   brew reinstall ta-lib

# %% [markdown]
# ### Virtual environment

# %% [markdown]
# #### Windows :

# %%
# %%bash
# python3.11 -m venv DataChallenge2023
# DataChallenge2023\Scripts\activate.bat
# # Check if virtual environment is activated
# python -c "import sys; print(sys.prefix)"
# python -m pip install -U pip
# pip install -r requirements.txt

# %% [markdown]
# #### MacOS (haven't been tested on Linux) :

# %% [markdown]
# ##### X-Code

# %%
try:
    # !xcode-select --version
except:
    print("Please install XCode in your terminal using : xcode-select --install")
# Out:
# xcode-select version 2403.

# %%
# %%bash
# # brew install python@3.11
# python3.11 -m venv DataChallenge2023
# source DataChallenge2023/bin/activate
# python -c "import sys; print(sys.prefix)"
# python -m pip install -U pip
# python -m pip install -r requirements.txt
# # To improve streamlit performance
# python -m pip install watchdog
# # To install lightgbm dependancies
# brew install libomp
# # Check if apple silicon in bash command
# if [[ $(uname -m) == "arm64" ]]; then
#     python -m pip install tensorflow-macos
#     python -m pip install tensorflow-metal
# fi
# Out:
# /Users/mathisderenne/Mon Drive/04 - Projet/RennesDataChallenge/DataChallenge2023
# Requirement already satisfied: pip in ./DataChallenge2023/lib/python3.11/site-packages (23.3.2)
# Collecting ipykernel (from -r requirements.txt (line 1))
#   Using cached ipykernel-6.29.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting seaborn (from -r requirements.txt (line 3))
#   Using cached seaborn-0.13.1-py3-none-any.whl.metadata (5.4 kB)
# Collecting scikit-learn (from -r requirements.txt (line 9))
#   Using cached scikit_learn-1.4.0-1-cp311-cp311-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting MacroRandomForest (from -r requirements.txt (line 10))
#   Using cached MacroRandomForest-1.0.6-py3-none-any.whl (13 kB)
# Collecting tensorflow (from -r requirements.txt (line 11))
#   Using cached tensorflow-2.15.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (3.6 kB)
# Collecting torch (from -r requirements.txt (line 12))
#   Using cached torch-2.1.2-cp311-none-macosx_11_0_arm64.whl.metadata (25 kB)
# Collecting streamlit (from -r requirements.txt (line 14))
#   Using cached streamlit-1.30.0-py2.py3-none-any.whl.metadata (8.2 kB)
# Collecting streamlit-extras (from -r requirements.txt (line 15))
#   Using cached streamlit_extras-0.3.6-py3-none-any.whl.metadata (3.7 kB)
# Collecting TA-Lib (from -r requirements.txt (line 17))
#   Using cached TA_Lib-0.4.28-cp311-cp311-macosx_11_0_arm64.whl
# Collecting openpyxl (from -r requirements.txt (line 18))
#   Using cached openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
# Collecting appnope (from ipykernel->-r requirements.txt (line 1))
#   Using cached appnope-0.1.3-py2.py3-none-any.whl (4.4 kB)
# Collecting comm>=0.1.1 (from ipykernel->-r requirements.txt (line 1))
#   Using cached comm-0.2.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting debugpy>=1.6.5 (from ipykernel->-r requirements.txt (line 1))
#   Using cached debugpy-1.8.0-cp311-cp311-macosx_11_0_universal2.whl.metadata (1.0 kB)
# Collecting ipython>=7.23.1 (from ipykernel->-r requirements.txt (line 1))
#   Using cached ipython-8.20.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyter-client>=6.1.12 (from ipykernel->-r requirements.txt (line 1))
#   Using cached jupyter_client-8.6.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting jupyter-core!=5.0.*,>=4.12 (from ipykernel->-r requirements.txt (line 1))
#   Using cached jupyter_core-5.7.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting matplotlib-inline>=0.1 (from ipykernel->-r requirements.txt (line 1))
#   Using cached matplotlib_inline-0.1.6-py3-none-any.whl (9.4 kB)
# Collecting nest-asyncio (from ipykernel->-r requirements.txt (line 1))
#   Using cached nest_asyncio-1.5.9-py3-none-any.whl.metadata (2.8 kB)
# Collecting packaging (from ipykernel->-r requirements.txt (line 1))
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting psutil (from ipykernel->-r requirements.txt (line 1))
#   Using cached psutil-5.9.7-cp38-abi3-macosx_11_0_arm64.whl.metadata (21 kB)
# Collecting pyzmq>=24 (from ipykernel->-r requirements.txt (line 1))
#   Using cached pyzmq-25.1.2-cp311-cp311-macosx_10_15_universal2.whl.metadata (4.9 kB)
# Collecting tornado>=6.1 (from ipykernel->-r requirements.txt (line 1))
#   Using cached tornado-6.4-cp38-abi3-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting traitlets>=5.4.0 (from ipykernel->-r requirements.txt (line 1))
#   Using cached traitlets-5.14.1-py3-none-any.whl.metadata (10 kB)
# Collecting numpy!=1.24.0,>=1.20 (from seaborn->-r requirements.txt (line 3))
#   Using cached numpy-1.26.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (115 kB)
# Collecting pandas>=1.2 (from seaborn->-r requirements.txt (line 3))
#   Using cached pandas-2.1.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (18 kB)
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn->-r requirements.txt (line 3))
#   Using cached matplotlib-3.8.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting scipy>=1.6.0 (from scikit-learn->-r requirements.txt (line 9))
#   Using cached scipy-1.11.4-cp311-cp311-macosx_12_0_arm64.whl.metadata (165 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->-r requirements.txt (line 9))
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->-r requirements.txt (line 9))
#   Using cached threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Collecting tensorflow-macos==2.15.0 (from tensorflow->-r requirements.txt (line 11))
#   Using cached tensorflow_macos-2.15.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (4.2 kB)
# Collecting absl-py>=1.0.0 (from tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers>=23.5.26 (from tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached gast-0.5.4-py3-none-any.whl (19 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting h5py>=2.9.0 (from tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached h5py-3.10.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.5 kB)
# Collecting libclang>=13.0.0 (from tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached libclang-16.0.6-py2.py3-none-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting ml-dtypes~=0.2.0 (from tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached ml_dtypes-0.2.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (20 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached protobuf-4.25.2-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11)) (65.5.0)
# Collecting six>=1.12.0 (from tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting termcolor>=1.1.0 (from tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting typing-extensions>=3.6.6 (from tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached typing_extensions-4.9.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached wrapt-1.14.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached tensorflow_io_gcs_filesystem-0.34.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (14 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached grpcio-1.60.0-cp311-cp311-macosx_10_10_universal2.whl.metadata (4.0 kB)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached tensorboard-2.15.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting filelock (from torch->-r requirements.txt (line 12))
#   Using cached filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting sympy (from torch->-r requirements.txt (line 12))
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Collecting networkx (from torch->-r requirements.txt (line 12))
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting jinja2 (from torch->-r requirements.txt (line 12))
#   Using cached Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting fsspec (from torch->-r requirements.txt (line 12))
#   Using cached fsspec-2023.12.2-py3-none-any.whl.metadata (6.8 kB)
# Collecting altair<6,>=4.0 (from streamlit->-r requirements.txt (line 14))
#   Using cached altair-5.2.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit->-r requirements.txt (line 14))
#   Using cached blinker-1.7.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting cachetools<6,>=4.0 (from streamlit->-r requirements.txt (line 14))
#   Using cached cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting click<9,>=7.0 (from streamlit->-r requirements.txt (line 14))
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting importlib-metadata<8,>=1.4 (from streamlit->-r requirements.txt (line 14))
#   Using cached importlib_metadata-7.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting pillow<11,>=7.1.0 (from streamlit->-r requirements.txt (line 14))
#   Using cached pillow-10.2.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.7 kB)
# Collecting pyarrow>=6.0 (from streamlit->-r requirements.txt (line 14))
#   Using cached pyarrow-14.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Collecting python-dateutil<3,>=2.7.3 (from streamlit->-r requirements.txt (line 14))
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting requests<3,>=2.27 (from streamlit->-r requirements.txt (line 14))
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting rich<14,>=10.14.0 (from streamlit->-r requirements.txt (line 14))
#   Using cached rich-13.7.0-py3-none-any.whl.metadata (18 kB)
# Collecting tenacity<9,>=8.1.0 (from streamlit->-r requirements.txt (line 14))
#   Using cached tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Collecting toml<2,>=0.10.1 (from streamlit->-r requirements.txt (line 14))
#   Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting tzlocal<6,>=1.1 (from streamlit->-r requirements.txt (line 14))
#   Using cached tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Collecting validators<1,>=0.2 (from streamlit->-r requirements.txt (line 14))
#   Using cached validators-0.22.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit->-r requirements.txt (line 14))
#   Using cached GitPython-3.1.41-py3-none-any.whl.metadata (14 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit->-r requirements.txt (line 14))
#   Using cached pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
# Collecting entrypoints>=0.4 (from streamlit-extras->-r requirements.txt (line 15))
#   Using cached entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Collecting htbuilder>=0.6.2 (from streamlit-extras->-r requirements.txt (line 15))
#   Using cached htbuilder-0.6.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting markdownlit>=0.0.5 (from streamlit-extras->-r requirements.txt (line 15))
#   Using cached markdownlit-0.0.7-py3-none-any.whl (15 kB)
# Collecting st-annotated-text>=3.0.0 (from streamlit-extras->-r requirements.txt (line 15))
#   Using cached st_annotated_text-4.0.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting streamlit-camera-input-live>=0.2.0 (from streamlit-extras->-r requirements.txt (line 15))
#   Using cached streamlit_camera_input_live-0.2.0-py3-none-any.whl (6.6 kB)
# Collecting streamlit-card>=0.0.4 (from streamlit-extras->-r requirements.txt (line 15))
#   Using cached streamlit_card-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting streamlit-embedcode>=0.1.2 (from streamlit-extras->-r requirements.txt (line 15))
#   Using cached streamlit_embedcode-0.1.2-py3-none-any.whl (3.5 kB)
# Collecting streamlit-faker>=0.0.2 (from streamlit-extras->-r requirements.txt (line 15))
#   Using cached streamlit_faker-0.0.3-py3-none-any.whl.metadata (2.0 kB)
# Collecting streamlit-image-coordinates<0.2.0,>=0.1.1 (from streamlit-extras->-r requirements.txt (line 15))
#   Using cached streamlit_image_coordinates-0.1.6-py3-none-any.whl.metadata (2.0 kB)
# Collecting streamlit-keyup>=0.1.9 (from streamlit-extras->-r requirements.txt (line 15))
#   Using cached streamlit_keyup-0.2.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting streamlit-toggle-switch>=1.0.2 (from streamlit-extras->-r requirements.txt (line 15))
#   Using cached streamlit_toggle_switch-1.0.2-py3-none-any.whl (635 kB)
# Collecting streamlit-vertical-slider>=1.0.2 (from streamlit-extras->-r requirements.txt (line 15))
#   Using cached streamlit_vertical_slider-2.5.5-py3-none-any.whl.metadata (2.2 kB)
# Collecting et-xmlfile (from openpyxl->-r requirements.txt (line 18))
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Collecting jsonschema>=3.0 (from altair<6,>=4.0->streamlit->-r requirements.txt (line 14))
#   Using cached jsonschema-4.21.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting toolz (from altair<6,>=4.0->streamlit->-r requirements.txt (line 14))
#   Using cached toolz-0.12.0-py3-none-any.whl (55 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 14))
#   Using cached gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Collecting more-itertools (from htbuilder>=0.6.2->streamlit-extras->-r requirements.txt (line 15))
#   Using cached more_itertools-10.2.0-py3-none-any.whl.metadata (34 kB)
# Collecting zipp>=0.5 (from importlib-metadata<8,>=1.4->streamlit->-r requirements.txt (line 14))
#   Using cached zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting decorator (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1))
#   Using cached decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1))
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting prompt-toolkit<3.1.0,>=3.0.41 (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1))
#   Using cached prompt_toolkit-3.0.43-py3-none-any.whl.metadata (6.5 kB)
# Collecting pygments>=2.4.0 (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1))
#   Using cached pygments-2.17.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting stack-data (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1))
#   Using cached stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting pexpect>4.3 (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1))
#   Using cached pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting platformdirs>=2.5 (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r requirements.txt (line 1))
#   Using cached platformdirs-4.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting markdown (from markdownlit>=0.0.5->streamlit-extras->-r requirements.txt (line 15))
#   Using cached Markdown-3.5.2-py3-none-any.whl.metadata (7.0 kB)
# Collecting lxml (from markdownlit>=0.0.5->streamlit-extras->-r requirements.txt (line 15))
#   Using cached lxml-5.1.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.5 kB)
# Collecting favicon (from markdownlit>=0.0.5->streamlit-extras->-r requirements.txt (line 15))
#   Using cached favicon-0.7.0-py2.py3-none-any.whl (5.9 kB)
# Collecting pymdown-extensions (from markdownlit>=0.0.5->streamlit-extras->-r requirements.txt (line 15))
#   Using cached pymdown_extensions-10.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 3))
#   Using cached contourpy-1.2.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 3))
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 3))
#   Using cached fonttools-4.47.2-cp311-cp311-macosx_10_9_universal2.whl.metadata (157 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 3))
#   Using cached kiwisolver-1.4.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 3))
#   Using cached pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting pytz>=2020.1 (from pandas>=1.2->seaborn->-r requirements.txt (line 3))
#   Using cached pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas>=1.2->seaborn->-r requirements.txt (line 3))
#   Using cached tzdata-2023.4-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch->-r requirements.txt (line 12))
#   Using cached MarkupSafe-2.1.3-cp311-cp311-macosx_10_9_universal2.whl.metadata (3.0 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.27->streamlit->-r requirements.txt (line 14))
#   Using cached charset_normalizer-3.3.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.27->streamlit->-r requirements.txt (line 14))
#   Using cached idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.27->streamlit->-r requirements.txt (line 14))
#   Using cached urllib3-2.1.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.27->streamlit->-r requirements.txt (line 14))
#   Using cached certifi-2023.11.17-py3-none-any.whl.metadata (2.2 kB)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit->-r requirements.txt (line 14))
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting faker (from streamlit-faker>=0.0.2->streamlit-extras->-r requirements.txt (line 15))
#   Using cached Faker-22.2.0-py3-none-any.whl.metadata (15 kB)
# Collecting mpmath>=0.19 (from sympy->torch->-r requirements.txt (line 12))
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached wheel-0.42.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 14))
#   Using cached smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting parso<0.9.0,>=0.8.3 (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1))
#   Using cached parso-0.8.3-py2.py3-none-any.whl (100 kB)
# Collecting attrs>=22.2.0 (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 14))
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 14))
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 14))
#   Using cached referencing-0.32.1-py3-none-any.whl.metadata (2.7 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 14))
#   Using cached rpds_py-0.17.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->-r requirements.txt (line 14))
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting ptyprocess>=0.5 (from pexpect>4.3->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1))
#   Using cached ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting wcwidth (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1))
#   Using cached wcwidth-0.2.13-py2.py3-none-any.whl.metadata (14 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached google_auth-2.26.2-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<2,>=0.5 (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached google_auth_oauthlib-1.2.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached protobuf-4.23.4-cp37-abi3-macosx_10_9_universal2.whl.metadata (540 bytes)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting beautifulsoup4>=4.7.0 (from favicon->markdownlit>=0.0.5->streamlit-extras->-r requirements.txt (line 15))
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting pyyaml (from pymdown-extensions->markdownlit>=0.0.5->streamlit-extras->-r requirements.txt (line 15))
#   Using cached PyYAML-6.0.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting executing>=1.2.0 (from stack-data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1))
#   Using cached executing-2.0.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting asttokens>=2.1.0 (from stack-data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1))
#   Using cached asttokens-2.4.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting pure-eval (from stack-data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1))
#   Using cached pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.7.0->favicon->markdownlit>=0.0.5->streamlit-extras->-r requirements.txt (line 15))
#   Using cached soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow->-r requirements.txt (line 11))
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached ipykernel-6.29.0-py3-none-any.whl (116 kB)
# Using cached seaborn-0.13.1-py3-none-any.whl (294 kB)
# Downloading scikit_learn-1.4.0-1-cp311-cp311-macosx_12_0_arm64.whl (10.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 3.1 MB/s eta 0:00:0000:0100:01
# Using cached tensorflow-2.15.0-cp311-cp311-macosx_12_0_arm64.whl (2.1 kB)
# Using cached tensorflow_macos-2.15.0-cp311-cp311-macosx_12_0_arm64.whl (208.8 MB)
# Using cached torch-2.1.2-cp311-none-macosx_11_0_arm64.whl (59.6 MB)
# Using cached streamlit-1.30.0-py2.py3-none-any.whl (8.4 MB)
# Using cached streamlit_extras-0.3.6-py3-none-any.whl (66 kB)
# Using cached altair-5.2.0-py3-none-any.whl (996 kB)
# Using cached blinker-1.7.0-py3-none-any.whl (13 kB)
# Using cached cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached comm-0.2.1-py3-none-any.whl (7.2 kB)
# Using cached debugpy-1.8.0-cp311-cp311-macosx_11_0_universal2.whl (2.1 MB)
# Using cached GitPython-3.1.41-py3-none-any.whl (196 kB)
# Using cached htbuilder-0.6.2-py3-none-any.whl (12 kB)
# Using cached importlib_metadata-7.0.1-py3-none-any.whl (23 kB)
# Using cached ipython-8.20.0-py3-none-any.whl (809 kB)
# Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Using cached jupyter_client-8.6.0-py3-none-any.whl (105 kB)
# Using cached jupyter_core-5.7.1-py3-none-any.whl (28 kB)
# Using cached matplotlib-3.8.2-cp311-cp311-macosx_11_0_arm64.whl (7.5 MB)
# Using cached numpy-1.26.3-cp311-cp311-macosx_11_0_arm64.whl (14.0 MB)
# Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Using cached pandas-2.1.4-cp311-cp311-macosx_11_0_arm64.whl (10.8 MB)
# Using cached pillow-10.2.0-cp311-cp311-macosx_11_0_arm64.whl (3.3 MB)
# Using cached pyarrow-14.0.2-cp311-cp311-macosx_11_0_arm64.whl (24.0 MB)
# Using cached Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Using cached pyzmq-25.1.2-cp311-cp311-macosx_10_15_universal2.whl (1.9 MB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached rich-13.7.0-py3-none-any.whl (240 kB)
# Using cached scipy-1.11.4-cp311-cp311-macosx_12_0_arm64.whl (29.7 MB)
# Using cached st_annotated_text-4.0.1-py3-none-any.whl (9.0 kB)
# Using cached streamlit_card-1.0.0-py3-none-any.whl (680 kB)
# Using cached streamlit_faker-0.0.3-py3-none-any.whl (14 kB)
# Using cached streamlit_image_coordinates-0.1.6-py3-none-any.whl (6.3 kB)
# Using cached streamlit_keyup-0.2.2-py3-none-any.whl (7.4 kB)
# Using cached streamlit_vertical_slider-2.5.5-py3-none-any.whl (1.8 MB)
# Using cached tenacity-8.2.3-py3-none-any.whl (24 kB)
# Using cached threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Using cached tornado-6.4-cp38-abi3-macosx_10_9_universal2.whl (433 kB)
# Using cached traitlets-5.14.1-py3-none-any.whl (85 kB)
# Using cached typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Using cached tzlocal-5.2-py3-none-any.whl (17 kB)
# Using cached validators-0.22.0-py3-none-any.whl (26 kB)
# Using cached filelock-3.13.1-py3-none-any.whl (11 kB)
# Using cached fsspec-2023.12.2-py3-none-any.whl (168 kB)
# Using cached nest_asyncio-1.5.9-py3-none-any.whl (5.3 kB)
# Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Using cached psutil-5.9.7-cp38-abi3-macosx_11_0_arm64.whl (246 kB)
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Using cached certifi-2023.11.17-py3-none-any.whl (162 kB)
# Using cached charset_normalizer-3.3.2-cp311-cp311-macosx_11_0_arm64.whl (118 kB)
# Using cached contourpy-1.2.0-cp311-cp311-macosx_11_0_arm64.whl (243 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Using cached fonttools-4.47.2-cp311-cp311-macosx_10_9_universal2.whl (2.8 MB)
# Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Using cached grpcio-1.60.0-cp311-cp311-macosx_10_10_universal2.whl (9.7 MB)
# Using cached h5py-3.10.0-cp311-cp311-macosx_11_0_arm64.whl (2.6 MB)
# Using cached idna-3.6-py3-none-any.whl (61 kB)
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# Using cached jsonschema-4.21.0-py3-none-any.whl (85 kB)
# Using cached keras-2.15.0-py3-none-any.whl (1.7 MB)
# Using cached kiwisolver-1.4.5-cp311-cp311-macosx_11_0_arm64.whl (66 kB)
# Using cached libclang-16.0.6-py2.py3-none-macosx_11_0_arm64.whl (20.6 MB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached MarkupSafe-2.1.3-cp311-cp311-macosx_10_9_universal2.whl (17 kB)
# Using cached ml_dtypes-0.2.0-cp311-cp311-macosx_10_9_universal2.whl (1.2 MB)
# Using cached pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
# Using cached platformdirs-4.1.0-py3-none-any.whl (17 kB)
# Using cached prompt_toolkit-3.0.43-py3-none-any.whl (386 kB)
# Using cached pygments-2.17.2-py3-none-any.whl (1.2 MB)
# Using cached pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Using cached pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
# Using cached tensorboard-2.15.1-py3-none-any.whl (5.5 MB)
# Using cached protobuf-4.23.4-cp37-abi3-macosx_10_9_universal2.whl (400 kB)
# Using cached Markdown-3.5.2-py3-none-any.whl (103 kB)
# Using cached tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
# Using cached tensorflow_io_gcs_filesystem-0.34.0-cp311-cp311-macosx_12_0_arm64.whl (1.9 MB)
# Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Using cached tzdata-2023.4-py2.py3-none-any.whl (346 kB)
# Using cached urllib3-2.1.0-py3-none-any.whl (104 kB)
# Using cached wrapt-1.14.1-cp311-cp311-macosx_11_0_arm64.whl (36 kB)
# Using cached zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Using cached Faker-22.2.0-py3-none-any.whl (1.7 MB)
# Using cached lxml-5.1.0-cp311-cp311-macosx_11_0_arm64.whl (4.5 MB)
# Using cached more_itertools-10.2.0-py3-none-any.whl (57 kB)
# Using cached pymdown_extensions-10.7-py3-none-any.whl (250 kB)
# Using cached stack_data-0.6.3-py3-none-any.whl (24 kB)
# Using cached asttokens-2.4.1-py2.py3-none-any.whl (27 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Using cached executing-2.0.1-py2.py3-none-any.whl (24 kB)
# Using cached google_auth-2.26.2-py2.py3-none-any.whl (186 kB)
# Using cached google_auth_oauthlib-1.2.0-py2.py3-none-any.whl (24 kB)
# Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Using cached referencing-0.32.1-py3-none-any.whl (26 kB)
# Using cached rpds_py-0.17.1-cp311-cp311-macosx_11_0_arm64.whl (352 kB)
# Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached werkzeug-3.0.1-py3-none-any.whl (226 kB)
# Using cached wheel-0.42.0-py3-none-any.whl (65 kB)
# Using cached PyYAML-6.0.1-cp311-cp311-macosx_11_0_arm64.whl (167 kB)
# Using cached wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# Using cached pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
# Installing collected packages: wcwidth, pytz, pure-eval, ptyprocess, mpmath, libclang, flatbuffers, appnope, zipp, wrapt, wheel, validators, urllib3, tzlocal, tzdata, typing-extensions, traitlets, tornado, toolz, toml, threadpoolctl, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, tenacity, sympy, soupsieve, smmap, six, rpds-py, pyzmq, pyyaml, pyparsing, pygments, pyasn1, psutil, protobuf, prompt-toolkit, platformdirs, pillow, pexpect, parso, packaging, oauthlib, numpy, networkx, nest-asyncio, more-itertools, mdurl, MarkupSafe, markdown, lxml, kiwisolver, keras, joblib, idna, grpcio, gast, fsspec, fonttools, filelock, executing, et-xmlfile, entrypoints, decorator, debugpy, cycler, click, charset-normalizer, certifi, cachetools, blinker, attrs, absl-py, werkzeug, TA-Lib, scipy, rsa, requests, referencing, python-dateutil, pymdown-extensions, pyasn1-modules, pyarrow, opt-einsum, openpyxl, ml-dtypes, matplotlib-inline, markdown-it-py, jupyter-core, jinja2, jedi, importlib-metadata, htbuilder, h5py, google-pasta, gitdb, contourpy, comm, beautifulsoup4, astunparse, asttokens, torch, stack-data, st-annotated-text, scikit-learn, rich, requests-oauthlib, pydeck, pandas, matplotlib, jupyter-client, jsonschema-specifications, google-auth, gitpython, favicon, faker, seaborn, MacroRandomForest, jsonschema, ipython, google-auth-oauthlib, tensorboard, ipykernel, altair, tensorflow-macos, streamlit, tensorflow, streamlit-vertical-slider, streamlit-toggle-switch, streamlit-keyup, streamlit-image-coordinates, streamlit-embedcode, streamlit-card, streamlit-camera-input-live, streamlit-faker, markdownlit, streamlit-extras
# Successfully installed MacroRandomForest-1.0.6 MarkupSafe-2.1.3 TA-Lib-0.4.28 absl-py-2.1.0 altair-5.2.0 appnope-0.1.3 asttokens-2.4.1 astunparse-1.6.3 attrs-23.2.0 beautifulsoup4-4.12.3 blinker-1.7.0 cachetools-5.3.2 certifi-2023.11.17 charset-normalizer-3.3.2 click-8.1.7 comm-0.2.1 contourpy-1.2.0 cycler-0.12.1 debugpy-1.8.0 decorator-5.1.1 entrypoints-0.4 et-xmlfile-1.1.0 executing-2.0.1 faker-22.2.0 favicon-0.7.0 filelock-3.13.1 flatbuffers-23.5.26 fonttools-4.47.2 fsspec-2023.12.2 gast-0.5.4 gitdb-4.0.11 gitpython-3.1.41 google-auth-2.26.2 google-auth-oauthlib-1.2.0 google-pasta-0.2.0 grpcio-1.60.0 h5py-3.10.0 htbuilder-0.6.2 idna-3.6 importlib-metadata-7.0.1 ipykernel-6.29.0 ipython-8.20.0 jedi-0.19.1 jinja2-3.1.3 joblib-1.3.2 jsonschema-4.21.0 jsonschema-specifications-2023.12.1 jupyter-client-8.6.0 jupyter-core-5.7.1 keras-2.15.0 kiwisolver-1.4.5 libclang-16.0.6 lxml-5.1.0 markdown-3.5.2 markdown-it-py-3.0.0 markdownlit-0.0.7 matplotlib-3.8.2 matplotlib-inline-0.1.6 mdurl-0.1.2 ml-dtypes-0.2.0 more-itertools-10.2.0 mpmath-1.3.0 nest-asyncio-1.5.9 networkx-3.2.1 numpy-1.26.3 oauthlib-3.2.2 openpyxl-3.1.2 opt-einsum-3.3.0 packaging-23.2 pandas-2.1.4 parso-0.8.3 pexpect-4.9.0 pillow-10.2.0 platformdirs-4.1.0 prompt-toolkit-3.0.43 protobuf-4.23.4 psutil-5.9.7 ptyprocess-0.7.0 pure-eval-0.2.2 pyarrow-14.0.2 pyasn1-0.5.1 pyasn1-modules-0.3.0 pydeck-0.8.1b0 pygments-2.17.2 pymdown-extensions-10.7 pyparsing-3.1.1 python-dateutil-2.8.2 pytz-2023.3.post1 pyyaml-6.0.1 pyzmq-25.1.2 referencing-0.32.1 requests-2.31.0 requests-oauthlib-1.3.1 rich-13.7.0 rpds-py-0.17.1 rsa-4.9 scikit-learn-1.4.0 scipy-1.11.4 seaborn-0.13.1 six-1.16.0 smmap-5.0.1 soupsieve-2.5 st-annotated-text-4.0.1 stack-data-0.6.3 streamlit-1.30.0 streamlit-camera-input-live-0.2.0 streamlit-card-1.0.0 streamlit-embedcode-0.1.2 streamlit-extras-0.3.6 streamlit-faker-0.0.3 streamlit-image-coordinates-0.1.6 streamlit-keyup-0.2.2 streamlit-toggle-switch-1.0.2 streamlit-vertical-slider-2.5.5 sympy-1.12 tenacity-8.2.3 tensorboard-2.15.1 tensorboard-data-server-0.7.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 tensorflow-io-gcs-filesystem-0.34.0 tensorflow-macos-2.15.0 termcolor-2.4.0 threadpoolctl-3.2.0 toml-0.10.2 toolz-0.12.0 torch-2.1.2 tornado-6.4 traitlets-5.14.1 typing-extensions-4.9.0 tzdata-2023.4 tzlocal-5.2 urllib3-2.1.0 validators-0.22.0 wcwidth-0.2.13 werkzeug-3.0.1 wheel-0.42.0 wrapt-1.14.1 zipp-3.17.0
# Collecting watchdog
#   Using cached watchdog-3.0.0-cp311-cp311-macosx_11_0_arm64.whl (91 kB)
# Installing collected packages: watchdog
# Successfully installed watchdog-3.0.0
# Warning: libomp 17.0.6 is already installed and up-to-date.
# To reinstall 17.0.6, run:
#   brew reinstall libomp
# Requirement already satisfied: tensorflow-macos in ./DataChallenge2023/lib/python3.11/site-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-macos) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-macos) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-macos) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-macos) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-macos) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-macos) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-macos) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-macos) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-macos) (1.26.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-macos) (3.3.0)
# Requirement already satisfied: packaging in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-macos) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-macos) (4.23.4)
# Requirement already satisfied: setuptools in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-macos) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-macos) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-macos) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-macos) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-macos) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-macos) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-macos) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-macos) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-macos) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-macos) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./DataChallenge2023/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow-macos) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos) (2.26.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./DataChallenge2023/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./DataChallenge2023/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./DataChallenge2023/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./DataChallenge2023/lib/python3.11/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./DataChallenge2023/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./DataChallenge2023/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./DataChallenge2023/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./DataChallenge2023/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./DataChallenge2023/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-macos) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./DataChallenge2023/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./DataChallenge2023/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos) (3.2.2)
# Collecting tensorflow-metal
#   Using cached tensorflow_metal-1.1.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (1.2 kB)
# Requirement already satisfied: wheel~=0.35 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-metal) (0.42.0)
# Requirement already satisfied: six>=1.15.0 in ./DataChallenge2023/lib/python3.11/site-packages (from tensorflow-metal) (1.16.0)
# Using cached tensorflow_metal-1.1.0-cp311-cp311-macosx_12_0_arm64.whl (1.4 MB)
# Installing collected packages: tensorflow-metal
# Successfully installed tensorflow-metal-1.1.0

# %% [markdown]
# For all users (select newly created kernel) :

# %%
from autoviz.AutoViz_Class import AutoViz_Class
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(100, 3), columns=['a', 'b', 'c'])
AV = AutoViz_Class()
AV.AutoViz(df)
